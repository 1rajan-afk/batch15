# %%
##working dir ----->staging/temporary area ---->remote repository
## git add ......?git commit -, "message"-----> git push origin master



#how to write commit message in a better way
#feat: add login page
#fix:bug fix in login page
#docs : update readme file
#style: code formation
#test : add test cases
##chore: update build task ,package manager configs,etx : no productive code change
#perf: improve performance


#fetch: retrieve changes from remote repository
#pull: fetch changes from remote repository and mege them into current branch




#stashing 
#rebase vs merge
#reset,revert
